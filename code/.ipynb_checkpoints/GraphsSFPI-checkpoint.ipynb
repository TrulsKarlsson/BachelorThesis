# %% [markdown]
# # LFW Dataset Graphs

# %% [markdown]
# ## ArcFace Graph

# %%
import matplotlib.pyplot as plt

# New threshold values
thresholds = [0.82, 0.7, 0.84, 0.6, 0.5, 0.4, 0.55, 0.52, 0.48, 0.45, 0.9]

# New metric values
metrics = {
    'F1-score': [0.6538461538461537, 0.65, 0.6728971962616822, 0.7058823529411764,
                 0.7096774193548387, 0.6666666666666666, 0.6874999999999999,
                 0.6984126984126985, 0.7096774193548387, 0.7096774193548387, 0.6666666666666667],
    'Precision': [0.53125, 0.65, 0.5373134328358209, 0.8571428571428571,
                  1.0, 1.0, 0.9166666666666666, 0.9565217391304348,
                  1.0, 1.0, 0.5135135135135135],
    'Recall': [0.85, 0.65, 0.9, 0.6, 0.55, 0.5, 0.55, 0.55, 0.55, 0.55, 0.95],
    'Accuracy': [0.55, 0.65, 0.5625, 0.75, 0.775, 0.75, 0.75, 0.7625,
                 0.775, 0.775, 0.525]
}

# Sorting thresholds and rearranging metric values accordingly
sorted_indices = sorted(range(len(thresholds)), key=lambda k: thresholds[k])
thresholds = [thresholds[i] for i in sorted_indices]
for metric_name in metrics:
    metrics[metric_name] = [metrics[metric_name][i] for i in sorted_indices]

max_f1_index = metrics['F1-score'].index(max(metrics['F1-score']))
best_threshold = thresholds[max_f1_index]

# Plotting
plt.figure(figsize=(10, 6))

# Plot F1-score
plt.plot(thresholds, metrics['F1-score'], color='blue', linestyle='-', label='F1-score')

# Plot Precision, Recall, and Accuracy
for i, (metric_name, values) in enumerate(metrics.items()):
    if metric_name != 'F1-score':
        linestyle = '--'
        if i == 1:
            color = 'orange'
        elif i == 2:
            color = 'green'
        else:
            color = 'red'
        plt.plot(thresholds, values, color=color, linestyle=linestyle, label=metric_name)

plt.axvline(x=best_threshold, color='black', linestyle='-', label='Best F1-score')

# Title and labels
plt.title('Performance Metrics vs Thresholds')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.savefig('ArcFaceGraphSFPI.png')
plt.show()

# %% [markdown]
# ## AdaFace Graph

# %%
import matplotlib.pyplot as plt

# New threshold values
thresholds = [0.815, 0.6, 0.7, 0.75, 0.65, 0.9, 0.725, 0.8, 0.83, 0.4]

# New metric values
metrics = {
    'F1-score': [0.7524752475247525, 0.7058823529411764, 0.7368421052631577, 0.7191011235955055,
                 0.7222222222222223, 0.7207207207207207, 0.7317073170731706, 0.7422680412371133,
                 0.7378640776699029, 0.6666666666666666],
    'Precision': [0.6229508196721312, 0.8571428571428571, 0.7777777777777778, 0.6530612244897959,
                  0.8125, 0.5633802816901409, 0.7142857142857143, 0.631578947368421,
                  0.6031746031746031, 1.0],
    'Recall': [0.95, 0.6, 0.7, 0.8, 0.65, 1.0, 0.75, 0.9, 0.95, 0.5],
    'Accuracy': [0.6875, 0.75, 0.75, 0.6875, 0.75, 0.6125, 0.725, 0.6875, 0.6625, 0.75]
}

# Sorting thresholds and rearranging metric values accordingly
sorted_indices = sorted(range(len(thresholds)), key=lambda k: thresholds[k])
thresholds = [thresholds[i] for i in sorted_indices]
for metric_name in metrics:
    metrics[metric_name] = [metrics[metric_name][i] for i in sorted_indices]

max_f1_index = metrics['F1-score'].index(max(metrics['F1-score']))
best_threshold = thresholds[max_f1_index]

plt.figure(figsize=(10, 6))

plt.plot(thresholds, metrics['F1-score'], color='blue', linestyle='-', label='F1-score')

for i, (metric_name, values) in enumerate(metrics.items()):
    if metric_name != 'F1-score':
        linestyle = '--'
        if i == 1:
            color = 'orange'
        elif i == 2:
            color = 'green'
        else:
            color = 'red'
        plt.plot(thresholds, values, color=color, linestyle=linestyle, label=metric_name)

plt.axvline(x=best_threshold, color='black', linestyle='-', label='Best F1-score')

# Title and labels
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.savefig('AdaFaceGraphSFPI.png')
plt.show()

# %% [markdown]
# ## MagFace Graph

# %%
import matplotlib.pyplot as plt

# New threshold values
thresholds = [0.8, 0.7, 0.9, 0.85, 0.6, 0.84, 0.83, 0.86, 0.4]

# New metric values
metrics = {
    'F1-score': [0.7111111111111111, 0.6666666666666667, 0.7037037037037037, 0.7346938775510204,
                 0.6956521739130435, 0.7422680412371133, 0.7157894736842104, 0.7128712871287128,
                 0.7096774193548387],
    'Precision': [0.64, 0.6842105263157895, 0.5588235294117647, 0.6206896551724138,
                  0.8275862068965517, 0.631578947368421, 0.6181818181818182, 0.5901639344262295,
                  1.0],
    'Recall': [0.8, 0.65, 0.95, 0.9, 0.6, 0.9, 0.85, 0.9, 0.55],
    'Accuracy': [0.675, 0.675, 0.6, 0.675, 0.7375, 0.6875, 0.6625, 0.6375, 0.775]
}

sorted_indices = sorted(range(len(thresholds)), key=lambda k: thresholds[k])
thresholds = [thresholds[i] for i in sorted_indices]
for metric_name in metrics:
    metrics[metric_name] = [metrics[metric_name][i] for i in sorted_indices]

max_f1_index = metrics['F1-score'].index(max(metrics['F1-score']))
best_threshold = thresholds[max_f1_index]

plt.figure(figsize=(10, 6))

plt.plot(thresholds, metrics['F1-score'], color='blue', linestyle='-', label='F1-score')

for i, (metric_name, values) in enumerate(metrics.items()):
    if metric_name != 'F1-score':
        linestyle = '--'
        if i == 1:
            color = 'orange'
        elif i == 2:
            color = 'green'
        else:
            color = 'red'
        plt.plot(thresholds, values, color=color, linestyle=linestyle, label=metric_name)

plt.axvline(x=best_threshold, color='black', linestyle='-', label='Best F1-score')

# Title and labels
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.savefig('MagFaceGraphSFPI.png')
plt.show()

# %% [markdown]
# ## ArcFace, AdaFace and MagFace and their corresponding F1-scores in a single graph

# %%
import matplotlib.pyplot as plt

# ArcFace data
arcface_thresholds = [0.82, 0.7, 0.84, 0.6, 0.5, 0.4, 0.55, 0.52, 0.48, 0.45, 0.9]
arcface_f1_scores = [0.6431478968792401, 0.8095238095238095, 0.8838643371017472, 0.8529698149951315,
                     0.8775510204081632, 0.8833849329205367, 0.8636363636363636, 0.8961748633879781,
                     0.8994594594594595, 0.8917470525187566]

# MagFace data
magface_thresholds = [0.8, 0.7, 0.9, 0.85, 0.6, 0.84, 0.83, 0.86, 0.4]
magface_f1_scores = [0.7111111111111111, 0.6666666666666667, 0.7037037037037037, 0.7346938775510204,
                 0.6956521739130435, 0.7422680412371133, 0.7157894736842104, 0.7128712871287128,
                 0.7096774193548387]

# AdaFace data       
adaface_thresholds = [0.815, 0.6, 0.7, 0.75, 0.65, 0.9, 0.725, 0.8, 0.83, 0.4]
adaface_f1_scores = [0.9457523029682702, 0.9283422459893047, 0.8687782805429864, 0.88,
                     0.9397089397089398, 0.9383215369059656, 0.9389865563598758, 0.942857142857143]

# Sorting thresholds and rearranging F1-score values accordingly
arcface_sorted_indices = sorted(range(len(arcface_thresholds)), key=lambda k: arcface_thresholds[k])
arcface_thresholds = [arcface_thresholds[i] for i in arcface_sorted_indices]
arcface_f1_scores = [arcface_f1_scores[i] for i in arcface_sorted_indices]

magface_sorted_indices = sorted(range(len(magface_thresholds)), key=lambda k: magface_thresholds[k])
magface_thresholds = [magface_thresholds[i] for i in magface_sorted_indices]
magface_f1_scores = [magface_f1_scores[i] for i in magface_sorted_indices]

adaface_sorted_indices = sorted(range(len(adaface_thresholds)), key=lambda k: adaface_thresholds[k])
adaface_thresholds = [adaface_thresholds[i] for i in adaface_sorted_indices]
adaface_f1_scores = [adaface_f1_scores[i] for i in adaface_sorted_indices]

# Plotting
plt.figure(figsize=(10, 6))

# Plot ArcFace
plt.plot(arcface_thresholds, arcface_f1_scores, label='ArcFace', marker='o')

# Plot MagFace
plt.plot(magface_thresholds, magface_f1_scores, label='MagFace', marker='o')

# Plot AdaFace
plt.plot(adaface_thresholds, adaface_f1_scores, label='AdaFace', marker='o')

# Title and labels
plt.title('F1-score Comparison for Different Models')
plt.xlabel('Threshold')
plt.ylabel('F1-score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 23
#      21 arcface_sorted_indices = sorted(range(len(arcface_thresholds)), key=lambda k: arcface_thresholds[k])
#      22 arcface_thresholds = [arcface_thresholds[i] for i in arcface_sorted_indices]
# ---> 23 arcface_f1_scores = [arcface_f1_scores[i] for i in arcface_sorted_indices]
#      25 magface_sorted_indices = sorted(range(len(magface_thresholds)), key=lambda k: magface_thresholds[k])
#      26 magface_thresholds = [magface_thresholds[i] for i in magface_sorted_indices]
#
# Cell In[5], line 23, in <listcomp>(.0)
#      21 arcface_sorted_indices = sorted(range(len(arcface_thresholds)), key=lambda k: arcface_thresholds[k])
#      22 arcface_thresholds = [arcface_thresholds[i] for i in arcface_sorted_indices]
# ---> 23 arcface_f1_scores = [arcface_f1_scores[i] for i in arcface_sorted_indices]
# ...

# %%
import matplotlib.pyplot as plt

# ArcFace data
arcface_thresholds = [0.82, 0.7, 0.84, 0.6, 0.5, 0.4, 0.55, 0.52, 0.48, 0.45, 0.9]
arcface_f1_scores = [0.6538461538461537, 0.65, 0.6728971962616822, 0.7058823529411764,
                 0.7096774193548387, 0.6666666666666666, 0.6874999999999999,
                 0.6984126984126985, 0.7096774193548387, 0.7096774193548387, 0.6666666666666667]

# MagFace data
magface_thresholds = [0.8, 0.7, 0.9, 0.85, 0.6, 0.84, 0.83, 0.86, 0.4]
magface_f1_scores = [0.7111111111111111, 0.6666666666666667, 0.7037037037037037, 0.7346938775510204,
                 0.6956521739130435, 0.7422680412371133, 0.7157894736842104, 0.7128712871287128,
                 0.7096774193548387]

# AdaFace data       
adaface_thresholds = [0.815, 0.6, 0.7, 0.75, 0.65, 0.9, 0.725, 0.8, 0.83, 0.4]
adaface_f1_scores = [0.7524752475247525, 0.7058823529411764, 0.7368421052631577, 0.7191011235955055,
                 0.7222222222222223, 0.7207207207207207, 0.7317073170731706, 0.7422680412371133,
                 0.7378640776699029, 0.6666666666666666]

# Sorting thresholds and rearranging F1-score values accordingly
arcface_sorted_indices = sorted(range(len(arcface_thresholds)), key=lambda k: arcface_thresholds[k])
arcface_thresholds = [arcface_thresholds[i] for i in arcface_sorted_indices]
arcface_f1_scores = [arcface_f1_scores[i] for i in arcface_sorted_indices]

magface_sorted_indices = sorted(range(len(magface_thresholds)), key=lambda k: magface_thresholds[k])
magface_thresholds = [magface_thresholds[i] for i in magface_sorted_indices]
magface_f1_scores = [magface_f1_scores[i] for i in magface_sorted_indices]

adaface_sorted_indices = sorted(range(len(adaface_thresholds)), key=lambda k: adaface_thresholds[k])
adaface_thresholds = [adaface_thresholds[i] for i in adaface_sorted_indices]
adaface_f1_scores = [adaface_f1_scores[i] for i in adaface_sorted_indices]

# Find the threshold where F1-score is highest for each model
arcface_max_f1_index = arcface_f1_scores.index(max(arcface_f1_scores))
arcface_best_threshold = arcface_thresholds[arcface_max_f1_index]

magface_max_f1_index = magface_f1_scores.index(max(magface_f1_scores))
magface_best_threshold = magface_thresholds[magface_max_f1_index]

adaface_max_f1_index = adaface_f1_scores.index(max(adaface_f1_scores))
adaface_best_threshold = adaface_thresholds[adaface_max_f1_index]

# Plotting
plt.figure(figsize=(10, 6))

# Plot ArcFace
plt.plot(arcface_thresholds, arcface_f1_scores, label='ArcFace')#, marker='o')

# Plot MagFace
plt.plot(magface_thresholds, magface_f1_scores, label='MagFace')#, marker='o')

# Plot AdaFace
plt.plot(adaface_thresholds, adaface_f1_scores, label='AdaFace')#, marker='o')

# Plot vertical lines for the thresholds with highest F1-score for each model
plt.axvline(x=arcface_best_threshold, color='blue', linestyle='--', label='ArcFace Best F1-score')
plt.axvline(x=magface_best_threshold, color='orange', linestyle='--', label='MagFace Best F1-score')
plt.axvline(x=adaface_best_threshold, color='green', linestyle='--', label='AdaFace Best F1-score')

# Title and labels
plt.xlabel('Threshold')
plt.ylabel('F1-score')
plt.legend()
plt.grid(True)
plt.savefig('F1-scoresSPFI.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 31
#      29 adaface_sorted_indices = sorted(range(len(adaface_thresholds)), key=lambda k: adaface_thresholds[k])
#      30 adaface_thresholds = [adaface_thresholds[i] for i in adaface_sorted_indices]
# ---> 31 adaface_f1_scores = [adaface_f1_scores[i] for i in adaface_sorted_indices]
#      33 # Find the threshold where F1-score is highest for each model
#      34 arcface_max_f1_index = arcface_f1_scores.index(max(arcface_f1_scores))
#
# Cell In[5], line 31, in <listcomp>(.0)
#      29 adaface_sorted_indices = sorted(range(len(adaface_thresholds)), key=lambda k: adaface_thresholds[k])
#      30 adaface_thresholds = [adaface_thresholds[i] for i in adaface_sorted_indices]
# ---> 31 adaface_f1_scores = [adaface_f1_scores[i] for i in adaface_sorted_indices]
# ...

# %%
# TODO
# 1: Kör en 0.9 MagFace
# 2: Kör en 0.6 AdaFace
