# %%
import pandas as pd

# %%
df = pd.read_csv("master.csv")

# %%
df.head()
# Out:
#       file_x     file_y Decision
# 0  img20.jpg  img21.jpg      Yes
# 1  img16.jpg  img17.jpg      Yes
# 2   img3.jpg  img12.jpg      Yes
# 3  img22.jpg  img23.jpg      Yes
# 4  img24.jpg  img25.jpg      Yes

# %%
df.tail()
# Out:
#         file_x    file_y Decision
# 295  img15.jpg  img9.jpg       No
# 296  img18.jpg  img8.jpg       No
# 297  img18.jpg  img9.jpg       No
# 298  img19.jpg  img8.jpg       No
# 299  img19.jpg  img9.jpg       No

# %%
df.shape
# Out:
# (300, 3)

# %%
df.Decision.value_counts()
# Out:
# Decision
# No     262
# Yes     38
# Name: count, dtype: int64

# %%
from PipelineMain import pipeline

# %%
instances = df[['file_x', 'file_y']].values.tolist()

# %%
instances
# Out:
# [['img20.jpg', 'img21.jpg'],
#  ['img16.jpg', 'img17.jpg'],
#  ['img3.jpg', 'img12.jpg'],
#  ['img22.jpg', 'img23.jpg'],
#  ['img24.jpg', 'img25.jpg'],
#  ['img1.jpg', 'img2.jpg'],
#  ['img1.jpg', 'img4.jpg'],
#  ['img1.jpg', 'img5.jpg'],
#  ['img1.jpg', 'img6.jpg'],
#  ['img1.jpg', 'img7.jpg'],
#  ['img1.jpg', 'img10.jpg'],
#  ['img1.jpg', 'img11.jpg'],
#  ['img2.jpg', 'img4.jpg'],
#  ['img2.jpg', 'img5.jpg'],
#  ['img2.jpg', 'img6.jpg'],
#  ['img2.jpg', 'img7.jpg'],
#  ['img2.jpg', 'img10.jpg'],
#  ['img2.jpg', 'img11.jpg'],
#  ['img4.jpg', 'img5.jpg'],
#  ['img4.jpg', 'img6.jpg'],
#  ['img4.jpg', 'img7.jpg'],
#  ['img4.jpg', 'img10.jpg'],
#  ['img4.jpg', 'img11.jpg'],
#  ['img5.jpg', 'img6.jpg'],
#  ['img5.jpg', 'img7.jpg'],
#  ['img5.jpg', 'img10.jpg'],
#  ['img5.jpg', 'img11.jpg'],
#  ['img6.jpg', 'img7.jpg'],
#  ['img6.jpg', 'img10.jpg'],
#  ['img6.jpg', 'img11.jpg'],
#  ['img7.jpg', 'img10.jpg'],
#  ['img7.jpg', 'img11.jpg'],
#  ['img10.jpg', 'img11.jpg'],
# ...

# %%
results = []

for pair in instances:
    image1_path, image2_path = pair
    
    # Call the pipeline function with the current pair of image paths
    result = pipeline("thresholdImages/" + image1_path, "thresholdImages/" + image2_path)
    
    # Append the return values to the results list
    results.append(result)
# Out:
# Image 1 started...
# 1/1 [==============================] - 2s 2s/step
# Representation done...
#
# Image 2 started...
# 1/1 [==============================] - 0s 60ms/step
# Representation done...
#
# Verification done...
#
# Image 1 started...
# 1/1 [==============================] - 0s 59ms/step
# Representation done...
#
# Image 2 started...
# 1/1 [==============================] - 0s 59ms/step
# Representation done...
#
# Verification done...
#
# Image 1 started...
# 1/1 [==============================] - 0s 58ms/step
# Representation done...
#
# Image 2 started...
# 1/1 [==============================] - 0s 61ms/step
# Representation done...
#
# Verification done...
#
# Image 1 started...
# 1/1 [==============================] - 0s 59ms/step
# Representation done...
#
# Image 2 started...
# 1/1 [==============================] - 0s 109ms/step
# Representation done...
#
# Verification done...
#
# Image 1 started...
# 1/1 [==============================] - 0s 60ms/step
 (False, False, 0.055958449840545654),
 (False, False, 0.0487019419670105),
 (False, False, 0.05106508731842041),
 (False, False, 0.09549206495285034),
 (False, False, 0.05030626058578491),
 (False, False, 0.06204628944396973),
 (False, False, 0.1251268982887268),
 (False, False, 0.08273154497146606)]

# %%
results
# Out:
# [(True, False, 0.03646153211593628),
#  (False, False, 0.05381608009338379),
#  (True, False, 0.02715390920639038),
#  (True, False, 0.0212213397026062),
#  (False, False, 0.10888183116912842),
#  (False, False, 0.04839271306991577),
#  (False, False, 0.04683828353881836),
#  (False, False, 0.04331099987030029),
#  (False, False, 0.043934762477874756),
#  (False, False, 0.0592116117477417),
#  (True, False, 0.03746765851974487),
#  (False, False, 0.06843692064285278),
#  (True, False, 0.034523963928222656),
#  (True, False, 0.02758657932281494),
#  (True, False, 0.012076616287231445),
#  (True, False, 0.01660311222076416),
#  (True, False, 0.03179943561553955),
#  (False, False, 0.05300635099411011),
#  (True, False, 0.02569645643234253),
#  (False, False, 0.04106348752975464),
#  (False, False, 0.05981653928756714),
#  (True, False, 0.009724736213684082),
#  (False, False, 0.058974504470825195),
#  (True, False, 0.030197739601135254),
#  (False, False, 0.0422634482383728),
# ...

# %%
distances = []
for i in range(0, len(instances)):
    distance = round(results[i][2], 4)
    distances.append(distance)

# %%
df["distance"] = distances

# %%
df.head()
# Out:
#       file_x     file_y Decision  distance
# 0  img20.jpg  img21.jpg      Yes    0.0365
# 1  img16.jpg  img17.jpg      Yes    0.0538
# 2   img3.jpg  img12.jpg      Yes    0.0272
# 3  img22.jpg  img23.jpg      Yes    0.0212
# 4  img24.jpg  img25.jpg      Yes    0.1089

# %%
import matplotlib.pyplot as plt
df[df.Decision == 'Yes'].distance.plot.kde(color='blue', label='Yes')

# Plot KDE for 'No' class with red color
df[df.Decision == 'No'].distance.plot.kde(color='red', label='No')

# Add legend to the plot
plt.legend()

# Add labels and title
plt.xlabel('Distance')
plt.ylabel('Density')
plt.title('KDE Plot of Distances for Yes and No Classes')

# Show the plot
plt.show()

# %%
# Lets find the best split point between the "Yes" and "No" class.
from chefboost import Chefboost as chef

# %%
config = {'algorithm': 'C4.5'}

# %%
tmp_df = df[["distance", "Decision"]]

# %%
model = chef.fit(tmp_df, config)
# Out:
# 24-04-25 14:42:33 - [INFO]: 4 CPU cores will be allocated in parallel running
# 24-04-25 14:42:33 - C4.5 tree is going to be built...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 model = chef.fit(tmp_df, config)
#
# File ~/Exjobb/BachelorThesis/code/chefboost/chefboost/Chefboost.py:275, in fit(df, config, target_label, validation_df, silent)
#     272         json_file = "outputs/rules/rules.json"
#     273         functions.createFile(json_file, "[\n")
# --> 275     trees = Training.buildDecisionTree(
#     276         df,
#     277         root=root,
#     278         file=file,
#     279         config=config,
#     280         dataset_features=dataset_features,
#     281         parent_level=0,
#     282         leaf_id=0,
#     283         parents="root",
#     284         validation_df=validation_df,
# ...

# %%
# Statistical approach
tp_mean = round(df[df.Decision == "Yes"]["distance"].mean(), 4)
tp_std = round(df[df.Decision == "Yes"]["distance"].std(), 4)
fp_mean = round(df[df.Decision == "No"]["distance"].mean(), 4)
fp_std = round(df[df.Decision == "No"]["distance"].std(), 4)

# %%
sigma = 1
threshold = round(tp_mean + sigma * tp_std, 4)

# %%
threshold
# Out:
# 0.0669
